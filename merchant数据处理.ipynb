# %%
import numpy as np
import pandas as pd
import datetime
from datetime import date, datetime
import gc
import matplotlib.pyplot as plt
import seaborn as sns
import lightgbm as lgb
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import mean_squared_error
import warnings
from sklearn.model_selection import KFold
import workalendar
from workalendar.america import Brazil

warnings.filterwarnings('ignore')
np.random.seed(4590)

# %%
def reduce_mem_usage(df, verbose=True):
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    start_mem = df.memory_usage().sum() / 1024**2    
    for col in df.columns:
        col_type = df[col].dtypes
        if col_type in numerics:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)    
    end_mem = df.memory_usage().sum() / 1024**2
    if verbose: print('Mem. usage decreased to {:5.2f} Mb ({:.1f}% reduction)'.format(end_mem, 100 * (start_mem - end_mem) / start_mem))
    return df

# %%
hist = pd.read_csv('historical_transactions.csv')
new= pd.read_csv('new_merchant_transactions.csv')

# %%
hist = reduce_mem_usage(hist)
new = reduce_mem_usage(new)
# Out:
# Mem. usage decreased to 1749.11 Mb (43.7% reduction)
# Mem. usage decreased to 114.20 Mb (45.5% reduction)

# %%
hist.head()
# Out:
#   authorized_flag          card_id  city_id category_1  installments  \
# 0               Y  C_ID_4e6213e9bc       88          N             0
# 1               Y  C_ID_4e6213e9bc       88          N             0
# 2               Y  C_ID_4e6213e9bc       88          N             0
# 3               Y  C_ID_4e6213e9bc       88          N             0
# 4               Y  C_ID_4e6213e9bc       88          N             0
#
#   category_3  merchant_category_id      merchant_id  month_lag  \
# 0          A                    80  M_ID_e020e9b302         -8
# 1          A                   367  M_ID_86ec983688         -7
# 2          A                    80  M_ID_979ed661fc         -6
# 3          A                   560  M_ID_e6d5ae8ea6         -5
# 4          A                    80  M_ID_e020e9b302        -11
#
#    purchase_amount        purchase_date  category_2  state_id  subsector_id
# 0        -0.703331  2017-06-25 15:33:07         1.0        16            37
# 1        -0.733128  2017-07-15 12:10:45         1.0        16            16
# 2        -0.720386  2017-08-09 22:04:29         1.0        16            37
# 3        -0.735352  2017-09-02 10:06:26         1.0        16            34
# 4        -0.722865  2017-03-10 01:14:19         1.0        16            37

# %%
for df in [hist,new]:
    df['category_2'].fillna(1.0,inplace=True)
    df['category_3'].fillna('A',inplace=True)
    df['merchant_id'].fillna('M_ID_00a6ca8a8a',inplace=True)

# %%
agg_fun = {'merchant_id': ['count']}
a=hist.groupby(['card_id','merchant_id']).agg(agg_fun)
a.columns = ['_'.join(col).strip() for col in a.columns.values]
a.reset_index(inplace=True)

# %%
a
# Out:
#                   card_id      merchant_id  merchant_id_count
# 0         C_ID_00007093c1  M_ID_0379adb435                  4
# 1         C_ID_00007093c1  M_ID_06a8d84366                  1
# 2         C_ID_00007093c1  M_ID_0dabc5a70c                  2
# 3         C_ID_00007093c1  M_ID_109e9d2b1d                  2
# 4         C_ID_00007093c1  M_ID_15446e939c                  4
# 5         C_ID_00007093c1  M_ID_1b440d74fb                  1
# 6         C_ID_00007093c1  M_ID_24e067cb2b                  1
# 7         C_ID_00007093c1  M_ID_2efbd71a00                  1
# 8         C_ID_00007093c1  M_ID_3c6556f2dd                  1
# 9         C_ID_00007093c1  M_ID_490fc654fb                  3
# 10        C_ID_00007093c1  M_ID_5357547c3e                  4
# 11        C_ID_00007093c1  M_ID_57df19bf28                 28
# 12        C_ID_00007093c1  M_ID_584ad6cd63                  4
# 13        C_ID_00007093c1  M_ID_58fa2d2ab7                  2
# 14        C_ID_00007093c1  M_ID_61f1337e5d                  1
# 15        C_ID_00007093c1  M_ID_69423b34e4                 11
# 16        C_ID_00007093c1  M_ID_6a1f75f661                  3
# 17        C_ID_00007093c1  M_ID_8261f7a734                  7
# 18        C_ID_00007093c1  M_ID_84e60960a3                  3
# 19        C_ID_00007093c1  M_ID_9400cf2342                 42
# 20        C_ID_00007093c1  M_ID_a33355a1b7                  4
# 21        C_ID_00007093c1  M_ID_a614b6d5b0                  1
# 22        C_ID_00007093c1  M_ID_bc3f2e986e                  3
# 23        C_ID_00007093c1  M_ID_c6ca6282e6                  1
# 24        C_ID_00007093c1  M_ID_d96a11b2df                  5
# 25        C_ID_00007093c1  M_ID_edeafa75d9                  1
# 26        C_ID_00007093c1  M_ID_ee8fcd02ca                  7
# 27        C_ID_00007093c1  M_ID_f5668a871f                  1
# 28        C_ID_00007093c1  M_ID_f6d28ce95b                  1
# 29        C_ID_0001238066  M_ID_010f6fda7d                  4
# ...                   ...              ...                ...
# 10992623  C_ID_ffff828181  M_ID_e4590daec2                  1
# 10992624  C_ID_ffff828181  M_ID_e73e337cb8                  2
# 10992625  C_ID_ffff828181  M_ID_ead3624f62                  1
# 10992626  C_ID_ffff828181  M_ID_eadbac8ee2                  2
# 10992627  C_ID_ffff828181  M_ID_eb421e5ec8                  1
# 10992628  C_ID_ffff828181  M_ID_ee5ab58628                  1
# 10992629  C_ID_ffff828181  M_ID_f33207423d                  2
# 10992630  C_ID_ffff828181  M_ID_f3d170cc3d                  2
# 10992631  C_ID_ffff828181  M_ID_f6866f4b22                  1
# 10992632  C_ID_ffff828181  M_ID_fc7d7969c3                  3
# 10992633  C_ID_ffff828181  M_ID_fe5592c749                  2
# 10992634  C_ID_fffffd5772  M_ID_00a6ca8a8a                  1
# 10992635  C_ID_fffffd5772  M_ID_310b8cc141                  1
# 10992636  C_ID_fffffd5772  M_ID_3841612e17                  2
# 10992637  C_ID_fffffd5772  M_ID_43d3146552                  4
# 10992638  C_ID_fffffd5772  M_ID_445742726b                 26
# 10992639  C_ID_fffffd5772  M_ID_55cb8d33dc                 15
# 10992640  C_ID_fffffd5772  M_ID_77c7152425                  4
# 10992641  C_ID_fffffd5772  M_ID_7840c5d7b0                  2
# 10992642  C_ID_fffffd5772  M_ID_8e03a902b7                  1
# 10992643  C_ID_fffffd5772  M_ID_9139332ccc                  2
# 10992644  C_ID_fffffd5772  M_ID_95bcc49b39                  1
# 10992645  C_ID_fffffd5772  M_ID_b737a61aa4                  1
# 10992646  C_ID_fffffd5772  M_ID_caa705da68                  1
# 10992647  C_ID_fffffd5772  M_ID_cc18e4b61e                  6
# 10992648  C_ID_fffffd5772  M_ID_d6626c9a19                  2
# 10992649  C_ID_fffffd5772  M_ID_db0fa76591                  5
# 10992650  C_ID_fffffd5772  M_ID_e80ebae5da                  4
# 10992651  C_ID_fffffd5772  M_ID_e8c10bd049                  1
# 10992652  C_ID_fffffd5772  M_ID_fc7d7969c3                  5
#
# [10992653 rows x 3 columns]

# %%
agg_fun = {'merchant_id': ['count']}
b=new.groupby(['card_id','merchant_id']).agg(agg_fun)
b.columns = ['_'.join(col).strip() for col in b.columns.values]
b.reset_index(inplace=True)

# %%
b
# Out:
#                  card_id      merchant_id  merchant_id_count
# 0        C_ID_00007093c1  M_ID_00a6ca8a8a                  1
# 1960036  C_ID_ffff828181  M_ID_3700a4ec5f                  1
# 1960037  C_ID_ffff828181  M_ID_64a0e7cd8e                  1
# 1960038  C_ID_ffff828181  M_ID_6a14caf978                  1
# 1960039  C_ID_ffff828181  M_ID_86c11f8b9c                  1
# 1960040  C_ID_ffff828181  M_ID_8a3341f4f2                  1
# 1960041  C_ID_ffff828181  M_ID_8b3f69594a                  1
# 1960042  C_ID_ffff828181  M_ID_f0fab17fd6                  1
# 1960043  C_ID_fffffd5772  M_ID_1208576963                  1
# 1960044  C_ID_fffffd5772  M_ID_bbc64a7bd8                  1
# 1960045  C_ID_fffffd5772  M_ID_c613085a2f                  1
#
# [1960046 rows x 3 columns]

# %%
c=pd.merge(a,b,on=['card_id','merchant_id'],how='outer')

# %%
c.shape
# Out:
# (12928941, 4)

# %%
c=c.fillna(0)

# %%
c['merchant_id_count']=c['merchant_id_count_x']+c['merchant_id_count_y']

# %%
d=c[['card_id','merchant_id','merchant_id_count']].copy()

# %%
agg_fun = {'merchant_id_count': ['max']}
e=d.groupby(['card_id']).agg(agg_fun)
e.columns = ['_'.join(col).strip() for col in e.columns.values]
e.reset_index(inplace=True)

# %%
e.rename(columns={'merchant_id_count_max':'merchant_id_count'},inplace=True)

# %%
c.drop_duplicates(subset=['card_id','merchant_id_count'],keep='first',inplace=True)

# %%
final=pd.merge(e,c,on=['card_id','merchant_id_count'],how='left')

# %%
final.rename(columns={'merchant_id':'merchant_id_max'},inplace=True)

# %%
final.head()
# Out:
#            card_id  merchant_id_max  merchant_id_count
# 0  C_ID_00007093c1  M_ID_9400cf2342               42.0
# 1  C_ID_0001238066  M_ID_d17aabd756               24.0
# 2  C_ID_0001506ef0  M_ID_b1fc88154d               13.0
# 3  C_ID_0001793786  M_ID_923d57de8d               17.0
# 4  C_ID_000183fdda  M_ID_f9cfe0a43b               13.0

# %%
final=final[['card_id','merchant_id','merchant_id_count']]

# %%
final.to_csv('national holidays/card_merchant.csv',index=False)

# %%
c.shape
# Out:
# (1981904, 5)

# %%
e.head()
# Out:
#            card_id  merchant_id_count
# 0  C_ID_00007093c1               42.0
# 1  C_ID_0001238066               24.0
# 2  C_ID_0001506ef0               13.0
# 3  C_ID_0001793786               17.0
# 4  C_ID_000183fdda               13.0

# %%
e.head()
# Out:
#            card_id  merchant_id_count_max
# 0  C_ID_00007093c1                   42.0
# 1  C_ID_0001238066                   24.0
# 2  C_ID_0001506ef0                   13.0
# 3  C_ID_0001793786                   17.0
# 4  C_ID_000183fdda                   13.0

# %%
c.head()
# Out:
#             card_id      merchant_id  merchant_id_count_x  \
# 0   C_ID_00007093c1  M_ID_0379adb435                  4.0
# 1   C_ID_00007093c1  M_ID_06a8d84366                  1.0
# 2   C_ID_00007093c1  M_ID_0dabc5a70c                  2.0
# 9   C_ID_00007093c1  M_ID_490fc654fb                  3.0
# 11  C_ID_00007093c1  M_ID_57df19bf28                 28.0
#
#     merchant_id_count_y  merchant_id_count
# 0                   0.0                4.0
# 1                   0.0                1.0
# 2                   0.0                2.0
# 9                   0.0                3.0
# 11                  0.0               28.0
